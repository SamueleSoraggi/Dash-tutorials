# %%
import pandas as pd

df_car = pd.read_csv('./Cars.csv')[ ['Make', 'Modle', 'Year_from', 'Year_to', 'Series', 'Trim', 'battery_capacity_KW_per_h',
       'electric_range_km', 'charging_time_h', 'country_of_origin', 'acceleration_0_100_km/h_s',
       'max_speed_km_per_h', 'city_fuel_per_100km_l', 'CO2_emissions_g/km', 'turning_circle_m', 'full_weight_kg'] ]
# Out:
# /tmp/ipykernel_9810/4042024326.py:3: DtypeWarning: Columns (9,11,12,13,14,15,16,17,19,20,24,27,29,33,43,44,47,49,51,69,75,77) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_car = pd.read_csv('./Cars.csv')[ ['Make', 'Modle', 'Series', 'Trim', 'battery_capacity_KW_per_h',

# %%
df_car
# Out:
#        id_trim Make     Modle    Generation  Year_from  Year_to       Series  \
# 0            1   AC       ACE  1 generation     1993.0   2000.0    Cabriolet
# 1            2   AC       ACE  1 generation     1993.0   2000.0    Cabriolet
# 2            3   AC       ACE  1 generation     1993.0   2000.0    Cabriolet
# 3            4   AC       ACE  1 generation     1993.0   2000.0     Roadster
# 4            5   AC       ACE  1 generation     1993.0   2000.0     Roadster
# ...        ...  ...       ...           ...        ...      ...          ...
# 70818    70983   ZX  Landmark  1 generation     2007.0   2009.0  SUV 5 doors
# 70819    70984   ZX  Landmark  1 generation     2007.0   2009.0  SUV 5 doors
# 70820    70985   ZX  Landmark  1 generation     2007.0   2009.0  SUV 5 doors
# 70821    70986   ZX  Landmark  1 generation     2007.0   2009.0  SUV 5 doors
# 70822    70987   ZX  Landmark  1 generation     2007.0   2009.0  SUV 5 doors
#
#              Trim  Body_type load_height_mm  ... front_suspension  \
# 0          3.5 MT  Cabriolet            NaN  ...  Helical springs
# 1          4.6 MT  Cabriolet            NaN  ...  Helical springs
# 2          4.9 AT  Cabriolet            NaN  ...  Helical springs
# 3          2.9 AT        NaN            NaN  ...              NaN
# 4          2.9 MT        NaN            NaN  ...              NaN
# ...           ...        ...            ...  ...              ...
# 70818  2.4 AT 4WD        NaN            NaN  ...              NaN
# 70819      2.4 MT        NaN            NaN  ...              NaN
# 70820  2.4 MT 4WD        NaN            NaN  ...              NaN
# 70821  3.2 AT 4WD        NaN            NaN  ...              NaN
# 70822  3.2 MT 4WD        NaN            NaN  ...              NaN
#
#       steering_type car_class country_of_origin number_of_doors  \
# 0               NaN       NaN               NaN             NaN
# 1               NaN       NaN               NaN             NaN
# 2               NaN       NaN               NaN             NaN
# 3               NaN       NaN               NaN             NaN
# 4               NaN       NaN               NaN             NaN
# ...             ...       ...               ...             ...
# 70818           NaN         J             China             5.0
# 70819           NaN         J             China             5.0
# 70820           NaN         J             China             5.0
# 70821           NaN         J             China             5.0
# 70822           NaN         J             China             5.0
#
#       safety_assessment rating_name battery_capacity_KW_per_h  \
# 0                   NaN         NaN                       NaN
# 1                   NaN         NaN                       NaN
# 2                   NaN         NaN                       NaN
# 3                   NaN         NaN                       NaN
# 4                   NaN         NaN                       NaN
# ...                 ...         ...                       ...
# 70818               NaN         NaN                       NaN
# 70819               NaN         NaN                       NaN
# 70820               NaN         NaN                       NaN
# 70821               NaN         NaN                       NaN
# 70822               NaN         NaN                       NaN
#
#       electric_range_km charging_time_h
# 0                   NaN             NaN
# 1                   NaN             NaN
# 2                   NaN             NaN
# 3                   NaN             NaN
# 4                   NaN             NaN
# ...                 ...             ...
# 70818               NaN             NaN
# 70819               NaN             NaN
# 70820               NaN             NaN
# 70821               NaN             NaN
# 70822               NaN             NaN
#
# [70823 rows x 78 columns]
